# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score,davies_bouldin_score
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Генериране на примерни данни
X, _ = make_blobs(n_samples=200, centers=3, random_state=42)

# Създаване на модел
kmeans = KMeans(n_clusters=3, random_state=42)
# Обучение на модела
kmeans.fit(X)

# Клъстерни етикети, т.е. номерът на клъстера, на който всеки екземпляр принаделжи
labels = kmeans.labels_
# Центрове на клъстерите
centers = kmeans.cluster_centers_

# WCSS (inertia)
wcss = kmeans.inertia_
print("WCSS:", wcss)
# Silhouette score
score = silhouette_score(X, labels)
print("Silhouette score:", score)
# Davies-Bouldin index
db_index = davies_bouldin_score(X, labels)
print("Davies-Bouldin index:", db_index)

# Визуализация
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(centers[:, 0], centers[:, 1], marker='X')
plt.show()
# Out:
# WCSS: 364.47332111317263
# Silhouette score: 0.8467003894636074
# Davies-Bouldin index: 0.22002745320431016
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
